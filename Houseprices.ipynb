# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

file_path = r'C:\Users\hp\Desktop\housing.csv'

# Read the CSV file
df = pd.read_csv(file_path)

df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

x= df.drop(['median_house_value'], axis=1)
y= df['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15186    -117.05     33.05                 6.0       7916.0          1293.0
# 5423     -118.41     34.03                20.0       4374.0          1311.0
# 2035     -119.74     36.73                42.0       1236.0           272.0
# 5211     -118.28     33.93                43.0        269.0            74.0
# 16610    -120.29     35.56                15.0       4760.0           871.0
# ...          ...       ...                 ...          ...             ...
# 2940     -118.96     35.37                32.0       1025.0           259.0
# 1294     -121.77     38.01                13.0       2983.0           534.0
# 13409    -117.48     34.10                30.0       2287.0           531.0
# 13744    -117.17     34.07                24.0       6573.0          1235.0
# 4039     -118.48     34.16                32.0       2108.0           309.0
#
#        population  households  median_income ocean_proximity  \
# 15186      2741.0      1204.0         5.6436       <1H OCEAN
# 5423       2165.0      1185.0         3.6019       <1H OCEAN
# 2035        946.0       261.0         2.0536          INLAND
# 5211        295.0        79.0         2.2969       <1H OCEAN
# 16610      2459.0       734.0         2.8110       <1H OCEAN
# ...           ...         ...            ...             ...
# 2940        874.0       236.0         1.9612          INLAND
# 1294       1417.0       510.0         3.9861          INLAND
# 13409      1796.0       503.0         2.5833          INLAND
# 13744      2904.0      1202.0         3.0651          INLAND
# 4039        769.0       274.0         8.7172       <1H OCEAN
#
#        median_house_value
# 15186            278600.0
# 5423             463600.0
# 2035              50000.0
# 5211              90600.0
# 16610            142100.0
# ...                   ...
# 2940              53400.0
# 1294             168100.0
# 13409             90600.0
# 13744            108000.0
# 4039             500001.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
numeric_data = train_data.select_dtypes(include=[float, int])
numeric_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924901           -0.113801     0.039895
# latitude            -0.924901  1.000000            0.017580    -0.032032
# housing_median_age  -0.113801  0.017580            1.000000    -0.357952
# total_rooms          0.039895 -0.032032           -0.357952     1.000000
# total_bedrooms       0.064720 -0.062811           -0.318325     0.930120
# population           0.094756 -0.103261           -0.293061     0.856712
# households           0.051793 -0.067324           -0.301210     0.919826
# median_income       -0.015809 -0.079800           -0.125359     0.200819
# median_house_value  -0.046259 -0.144038            0.100673     0.133758
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.064720    0.094756    0.051793      -0.015809
# latitude                 -0.062811   -0.103261   -0.067324      -0.079800
# housing_median_age       -0.318325   -0.293061   -0.301210      -0.125359
# total_rooms               0.930120    0.856712    0.919826       0.200819
# total_bedrooms            1.000000    0.874604    0.980159      -0.004436
# population                0.874604    1.000000    0.903394       0.009450
# households                0.980159    0.903394    1.000000       0.016740
# median_income            -0.004436    0.009450    0.016740       1.000000
# median_house_value        0.051178   -0.023555    0.066062       0.685329
#
#                     median_house_value
# longitude                    -0.046259
# latitude                     -0.144038
# housing_median_age            0.100673
# total_rooms                   0.133758
# total_bedrooms                0.051178
# population                   -0.023555
# households                    0.066062
# median_income                 0.685329
# median_house_value            1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns for correlation
numeric_data = train_data.select_dtypes(include=['float64', 'int64'
# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data = train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/train_data['total_rooms']
train_data['household_rooms'] = train_data['total_rooms']/train_data['households']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns for correlation
numeric_data = train_data.select_dtypes(include=['float64', 'int64'])

# Create the heatmap for the correlation matrix
plt.figure(figsize=(15, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap="YlGnBu")
plt.show()

# %% [raw]
# Applying Linear regression Model

# %%
from sklearn.preprocessing import LabelEncoder

# Encode the 'ocean_proximity' column
le = LabelEncoder()
train_data['ocean_proximity'] = le.fit_transform(train_data['ocean_proximity'])

# Define x_train and y_train
x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']

# Train the model
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train, y_train = train_data.drop(['median_house_value'], axis=1), train_data['median_house_value']
x_train_s = scaler.fit_transform(x_train)

reg = LinearRegression()
reg.fit(x_train_s, y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
import pandas as pd

# First check if 'ocean_proximity' is in the test_data
if 'ocean_proximity' in test_data.columns:
    # Apply one-hot encoding to 'ocean_proximity'
    test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity'], drop_first=True)).drop(['ocean_proximity'], axis=1)

# Apply log transformation to numerical columns
test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# Create new features
test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms'] / test_data['households']

# %%
x_test, y_test = train_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
x_test_s = scaler.transform(x_test)

# %%
reg.score(x_test, y_test)
# Out:
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -4059.6648316865135

# %%
x_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 15186    -117.05     33.05                 6.0     2.300259        2.099917
# 5423     -118.41     34.03                20.0     2.238970        2.101608
# 2035     -119.74     36.73                42.0     2.094385        1.888504
# 5211     -118.28     33.93                43.0     1.886831        1.671001
# 16610    -120.29     35.56                15.0     2.247940        2.050372
# ...          ...       ...                 ...          ...             ...
# 2940     -118.96     35.37                32.0     2.071085        1.881095
# 1294     -121.77     38.01                13.0     2.197338        1.985442
# 13409    -117.48     34.10                30.0     2.167388        1.984670
# 13744    -117.17     34.07                24.0     2.281451        2.094285
# 4039     -118.48     34.16                32.0     2.158018        1.907551
#
#        population  households  median_income  ocean_proximity  bedroom_ratio  \
# 15186    7.916443    7.094235         5.6436                0       0.912905
# 5423     7.680637    7.078342         3.6019                0       0.938649
# 2035     6.853299    5.568345         2.0536                1       0.901699
# 5211     5.690359    4.382027         2.2969                0       0.885613
# 16610    7.807917    6.599870         2.8110                0       0.912111
# ...           ...         ...            ...              ...            ...
# 2940     6.774224    5.468060         1.9612                1       0.908265
# 1294     7.257003    6.236370         3.9861                1       0.903567
# 13409    7.493874    6.222576         2.5833                1       0.915697
# 13744    7.974189    7.092574         3.0651                1       0.917962
# 4039     6.646391    5.616771         8.7172                0       0.883937
#
#        household_rooms
# 15186         0.324243
# 5423          0.316313
# 2035          0.376123
# 5211          0.430584
# 16610         0.340604
# ...                ...
# 2940          0.378760
# 1294          0.352342
# 13409         0.348310
# 13744         0.321668
# 4039          0.384210
#
# [16346 rows x 11 columns]

# %%
reg.score(x_test_s,y_test)
# Out:
# 0.6582084276345834

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(x_train_s, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test_s, y_test)
# Out:
# 0.9738752092100083

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Initialize the RandomForestRegressor
forest = RandomForestRegressor()

# Define the parameter grid for GridSearchCV
param_grid = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2, 4],
    "max_depth": [None, 4, 8]
}

# Set up GridSearchCV
grid_search = GridSearchCV(forest, param_grid, cv=5,
                          scoring="neg_mean_squared_error",
                          return_train_score=True)

# Fit GridSearchCV
grid_search.fit(x_train_s, y_train)

# %%
best_forest = grid_search.best_estimator_
best_forest

# %%
best_forest.score(x_test_s, y_test)

# %%
grid_search.best_estimator_.score(x_test_s, y_test)
